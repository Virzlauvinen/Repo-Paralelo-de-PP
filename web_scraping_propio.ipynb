# %%
# import libraries
import requests
from bs4 import BeautifulSoup
import csv
from datetime import datetime

# %%
# indicar la ruta
url_page = 'https://www.bolsamadrid.es/esp/aspx/Mercados/Precios.aspx?indice=ESI100000000'
# tarda 480 milisegundos
page = requests.get(url_page).text 
#Instancio Un objeto del tipo BS en la variable soup
soup = BeautifulSoup(page, "lxml")
# Obtenemos la tabla por un ID específico// Find es una funcios del objeto Soup
tabla = soup.find('table', attrs={'id': 'ctl00_Contenido_tblAcciones'})
tabla
# Out:
# <table cellpadding="3" cellspacing="0" class="TblPort" id="ctl00_Contenido_tblAcciones" width="100%">
# <tr align="center">
# <th scope="col">Nombre</th><th scope="col">Últ.</th><th scope="col">% Dif.</th><th scope="col">Máx.</th><th scope="col">Mín.</th><th scope="col">Volumen</th><th scope="col">Efectivo (miles €)</th><th scope="col">Fecha</th><th class="Ult" scope="col">Hora</th>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0125220311">ACCIONA</a></td><td>148,1000</td><td class="DifClSb">3,06</td><td>149,5000</td><td>144,6000</td><td>104.248</td><td>15.336,66</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlBj"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0132105018">ACERINOX</a></td><td>11,3550</td><td class="DifClBj">-0,26</td><td>11,4900</td><td>11,2700</td><td>636.605</td><td>7.222,28</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0167050915">ACS</a></td><td>23,4000</td><td class="DifClSb">4,00</td><td>23,5300</td><td>22,6700</td><td>621.275</td><td>14.472,44</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0105046009">AENA</a></td><td>133,5000</td><td class="DifClSb">1,56</td><td>134,1000</td><td>132,0000</td><td>116.247</td><td>15.496,01</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0157097017">ALMIRALL</a></td><td>13,9400</td><td class="DifClSb">0,65</td><td>14,0600</td><td>13,7600</td><td>232.350</td><td>3.233,79</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0109067019">AMADEUS</a></td><td>52,0000</td><td class="DifClSb">0,62</td><td>52,5800</td><td>51,6400</td><td>1.604.055</td><td>83.554,13</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlBj"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=LU1598757687">ARCELORMIT.</a></td><td>27,9050</td><td class="DifClBj">-0,02</td><td>28,3750</td><td>27,7650</td><td>323.147</td><td>9.047,48</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0113900J37">B.SANTANDER</a></td><td>3,1140</td><td class="DifClSb">2,33</td><td>3,1140</td><td>3,0485</td><td>27.723.071</td><td>85.915,59</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0113860A34">BA.SABADELL</a></td><td>0,6008</td><td class="DifClSb">3,09</td><td>0,6016</td><td>0,5824</td><td>16.879.144</td><td>10.027,85</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0113679I37">BANKINTER</a></td><td>4,9430</td><td class="DifClSb">1,54</td><td>4,9500</td><td>4,8570</td><td>1.138.183</td><td>5.599,69</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0113211835">BBVA</a></td><td>5,5970</td><td class="DifClSb">1,76</td><td>5,6020</td><td>5,4820</td><td>14.537.552</td><td>80.853,53</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0140609019">CAIXABANK</a></td><td>2,6420</td><td class="DifClSb">2,44</td><td>2,6420</td><td>2,5760</td><td>6.270.472</td><td>16.425,73</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlBj"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0105066007">CELLNEX</a></td><td>56,6600</td><td class="DifClBj">-1,01</td><td>57,5600</td><td>56,6600</td><td>627.918</td><td>35.706,91</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0105630315">CIE AUTOMOT.</a></td><td>23,7000</td><td class="DifClSb">0,77</td><td>23,8000</td><td>23,4400</td><td>94.221</td><td>2.227,12</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES
td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0178430E18">TELEFONICA</a></td><td>4,1610</td><td class="DifClSb">0,98</td><td>4,2030</td><td>4,1065</td><td>8.730.049</td><td>36.348,27</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr><tr align="right">
# <td align="left" class="DifFlSb"><a href="/esp/aspx/Empresas/FichaValor.aspx?ISIN=ES0184262212">VISCOFAN</a></td><td>59,5000</td><td class="DifClSb">0,25</td><td>60,0500</td><td>59,3000</td><td>38.605</td><td>2.299,47</td><td align="center">13/09/2021</td><td align="center" class="Ult">Cierre</td>
# </tr>
# </table>

# %%
#Recorremos la tabla creada en el punto anterior para crear un array (diccionario) con los datos que necesito.
nombre=""
util=0
dif=0
maximo = 0
minimo =0
fecha = ""

nroFila=0 # Flag se utiliza lara tener visibilidad de las iteraciones
# DEFINO ARRAY DONDE GUARDAR LOS DATOS DE CADA ITERACION
array=[]

for fila in tabla.find_all('tr'):
    # for row in  tabla.find_all("td")::
    nroCelda=0
    for celda in fila.find_all('td'):
        if nroCelda==0:
            nombre=celda.text
            print("nombre:", nombre)
        if nroCelda==1:
            util=celda.text
            print("util:", util)
        if nroCelda==2:
            dif=celda.text
            print("dif:", dif)
        if nroCelda==3:
            maximo=celda.text
            print("maximo:", maximo)
        if nroCelda==4:
            minimo=celda.text
            print("minimo:", minimo)
        if nroCelda==7:
            fecha=celda.text
            print("fecha:", fecha)
        nroCelda=nroCelda+1 # FLAG que incrementa la celda
    nroFila=nroFila+1 # Flag que incrementa la fila 
    # AGREGO/GUARDO LOS DATOS EN FORMATO DICCIONARIO EN EL ARRAY.
    array.append({"nombre": nombre, "util": util, "dif":dif, "maximo":maximo, "minimo":minimo, "fecha":fecha})
# Out:
# nombre: ACCIONA
# util: 148,1000
# dif: 3,06
# maximo: 149,5000
# minimo: 144,6000
# fecha: 13/09/2021
# nombre: ACERINOX
# util: 11,3550
# dif: -0,26
# maximo: 11,4900
# minimo: 11,2700
# fecha: 13/09/2021
# nombre: ACS
# util: 23,4000
# dif: 4,00
# maximo: 23,5300
# minimo: 22,6700
# fecha: 13/09/2021
# nombre: AENA
# util: 133,5000
# dif: 1,56
# maximo: 134,1000
# minimo: 132,0000
# fecha: 13/09/2021
# nombre: ALMIRALL
# util: 13,9400
# dif: 0,65
# maximo: 14,0600
# minimo: 13,7600
# fecha: 13/09/2021
# nombre: AMADEUS
# util: 52,0000
# dif: 0,62
# maximo: 52,5800
# minimo: 51,6400
# fecha: 13/09/2021
# nombre: ARCELORMIT.
# util: 27,9050
# dif: -0,02
# maximo: 28,3750
# minimo: 27,7650
# fecha: 13/09/2021
# nombre: B.SANTANDER
# util: 3,1140
# dif: 2,33
# maximo: 3,1140
# minimo: 3,0485
# fecha: 13/09/2021
# nombre: BA.SABADELL
# util: 0,6008
# dif: 3,09
# maximo: 0,6016
# minimo: 0,5824
# fecha: 13/09/2021
# nombre: BANKINTER
# util: 4,9430
# dif: 1,54
# maximo: 4,9500
# minimo: 4,8570
# fecha: 13/09/2021
# nombre: BBVA
# util: 5,5970
# fecha: 13/09/2021
# nombre: TELEFONICA
# util: 4,1610
# dif: 0,98
# maximo: 4,2030
# minimo: 4,1065
# fecha: 13/09/2021
# nombre: VISCOFAN
# util: 59,5000
# dif: 0,25
# maximo: 60,0500
# minimo: 59,3000
# fecha: 13/09/2021

# %%
# VEO COMO SE CREO EL ARRAY
array
# Out:
# [{'nombre': '', 'util': 0, 'dif': 0, 'maximo': 0, 'minimo': 0, 'fecha': ''},
#  {'nombre': 'ACCIONA',
#   'util': '148,1000',
#   'dif': '3,06',
#   'maximo': '149,5000',
#   'minimo': '144,6000',
#   'fecha': '13/09/2021'},
#  {'nombre': 'ACERINOX',
#   'util': '11,3550',
#   'dif': '-0,26',
#   'maximo': '11,4900',
#   'minimo': '11,2700',
#   'fecha': '13/09/2021'},
#  {'nombre': 'ACS',
#   'util': '23,4000',
#   'dif': '4,00',
#   'maximo': '23,5300',
#   'minimo': '22,6700',
#   'fecha': '13/09/2021'},
#  {'nombre': 'AENA',
#   'util': '133,5000',
#   'dif': '1,56',
#   'maximo': '134,1000',
#   'minimo': '132,0000',
#   'fecha': '13/09/2021'},
#  {'nombre': 'ALMIRALL',
#   'util': '13,9400',
#   'dif': '0,65',
#   'maximo': '14,0600',
#   'minimo': '13,7600',
#   'fecha': '13/09/2021'},
#  {'nombre': 'AMADEUS',
#   'util': '52,0000',
#   'dif': '0,62',
#   'maximo': '52,5800',
#   'minimo': '51,6400',
#   'fecha': '13/09/2021'},
#  {'nombre': 'ARCELORMIT.',
#   'util': '27,9050',
#   'dif': '-0,02',
#   'maximo': '28,3750',
#   'minimo': '27,7650',
#   'fecha': '13/09/2021'},
#  {'nombre': 'B.SANTANDER',
#   'util': '3,1140',
#   'dif': '2,33',
#   'maximo': '3,1140',
#   'minimo': '3,0485',
#   'fecha': '13/09/2021'},
#  {'nombre': 'BA.SABADELL',
#   'util': '0,6008',
#   'dif': '3,09',
#   'maximo': '0,6016',
#   'minimo': '0,5824',
#   'fecha': '13/09/2021'},
#  {'nombre': 'BANKINTER',
#   'util': '4,9430',
#   'dif': '1,54',
#   'maximo': '4,9500',
#   'minimo': '4,8570',
#   'fecha': '13/09/2021'},
#  {'nombre': 'BBVA',
#   'util': '5,5970',
#   'dif': '1,76',
#   'maximo': '5,6020',
#   'minimo': '5,4820',
#   'fecha': '13/09/2021'},
#  {'nombre': 'CAIXABANK',
#   'util': '2,6420',
#   'dif': '2,44',
#   'maximo': '2,6420',
#   'minimo': '2,5760',
#   'fecha': '13/09/2021'},
#  {'nombre': 'CELLNEX',
#   'util': '56,6600',
#   'dif': '-1,01',
#   'maximo': '57,5600',
#   'minimo': '56,6600',
#   'fecha': '13/09/2021'},
#  {'nombre': 'CIE AUTOMOT.',
#   'util': '23,7000',
#   'dif': '0,77',
#   'maximo': '23,8000',
#   'minimo': '23,4400',
#   'fecha': '13/09/2021'},
#  {'nombre': 'ENAGAS',
#   'util': '18,8900',
#   'dif': '1,42',
#   'maximo': '18,9350',
#   'minimo': '18,6450',
#   'fecha': '13/09/2021'},
#  {'nombre': 'ENDESA',
#   'util': '20,4700',
#   'dif': '1,64',
#   'maximo': '20,5900',
#   'minimo': '20,1400',
#   'fecha': '13/09/2021'},
#  {'nombre': 'FERROVIAL',
#   'util': '24,9100',
#   'dif': '1,59',
#   'maximo': '25,0800',
#   'minimo': '24,6000',
#   'fecha': '13/09/2021'},
#  {'nombre': 'FLUIDRA',
#   'util': '37,5500',
#   'dif': '0,54',
#   'maximo': '38,1000',
#   'minimo': '37,1000',
#   'fecha': '13/09/2021'},
#  {'nombre': 'GRIFOLS CL.A',
#   'util': '20,8900',
#   'dif': '2,00',
#   'maximo': '21,0300',
#   'minimo': '20,5300',
#   'fecha': '13/09/2021'},
#  {'nombre': 'IAG',
#   'util': '1,7380',
#   'dif': '2,03',
#   'maximo': '1,7405',
#   'minimo': '1,6600',
#   'fecha': '13/09/2021'},
#  {'nombre': 'IBERDROLA',
#   'util': '10,2550',
#   'dif': '1,84',
#   'maximo': '10,2850',
#   'minimo': '10,0950',
#   'fecha': '13/09/2021'},
#  {'nombre': 'INDITEX',
#   'util': '29,5000',
#   'dif': '0,27',
#   'maximo': '29,6900',
#   'minimo': '29,0000',
#   'fecha': '13/09/2021'},
#  {'nombre': 'INDRA A',
#   'util': '8,9850',
#   'dif': '1,53',
#   'maximo': '9,0450',
#   'minimo': '8,8550',
#   'fecha': '13/09/2021'},
#  {'nombre': 'INM.COLONIAL',
#   'util': '8,7350',
#   'dif': '3,93',
#   'maximo': '8,9050',
#   'minimo': '8,4250',
#   'fecha': '13/09/2021'},
#  {'nombre': 'MAPFRE',
#   'util': '1,8330',
#   'dif': '2,23',
#   'maximo': '1,8370',
#   'minimo': '1,8045',
#   'fecha': '13/09/2021'},
#  {'nombre': 'MELIA HOTELS',
#   'util': '5,7760',
#   'dif': '1,44',
#   'maximo': '5,7800',
#   'minimo': '5,6460',
#   'fecha': '13/09/2021'},
#  {'nombre': 'MERLIN',
#   'util': '9,2780',
#   'dif': '1,27',
#   'maximo': '9,2860',
#   'minimo': '9,0700',
#   'fecha': '13/09/2021'},
#  {'nombre': 'NATURGY',
#   'util': '21,9800',
#   'dif': '1,15',
#   'maximo': '22,0000',
#   'minimo': '21,7600',
#   'fecha': '13/09/2021'},
#  {'nombre': 'PHARMA MAR',
#   'util': '78,4600',
#   'dif': '-1,93',
#   'maximo': '80,5000',
#   'minimo': '78,0400',
#   'fecha': '13/09/2021'},
#  {'nombre': 'R.E.C.',
#   'util': '17,0600',
#   'dif': '1,22',
#   'maximo': '17,1650',
#   'minimo': '16,9150',
#   'fecha': '13/09/2021'},
#  {'nombre': 'REPSOL',
#   'util': '9,7830',
#   'dif': '3,52',
#   'maximo': '9,7860',
#   'minimo': '9,4410',
#   'fecha': '13/09/2021'},
#  {'nombre': 'SIEMENS GAME',
#   'util': '23,2200',
#   'dif': '1,98',
#   'maximo': '23,2700',
#   'minimo': '22,4900',
#   'fecha': '13/09/2021'},
#  {'nombre': 'SOLARIA',
#   'util': '15,4450',
#   'dif': '2,86',
#   'maximo': '15,5900',
#   'minimo': '14,9900',
#   'fecha': '13/09/2021'},
#  {'nombre': 'TELEFONICA',
#   'util': '4,1610',
#   'dif': '0,98',
#   'maximo': '4,2030',
#   'minimo': '4,1065',
#   'fecha': '13/09/2021'},
#  {'nombre': 'VISCOFAN',
#   'util': '59,5000',
#   'dif': '0,25',
#   'maximo': '60,0500',
#   'minimo': '59,3000',
#   'fecha': '13/09/2021'}]

# %%
# Abrimos el csv con open para que pueda agregar contenidos al final del archivo
# agrego el parametro newline="" para que no haga un salto de linea 
with open('bolsa_de_madrid.csv', 'a', newline="") as csv_file: # Abro/Creo archivo CSV al que llamare csv_file dentro de python
    writer = csv.writer(csv_file) # Estoy diciendo que escriba el archivo csv_file
    for row in array : # Recorro el diccionario linea por linea.
        #print(row['name'])
        
        #if(row['name'] != ""): # Como el primer registro es null y no quiero que se escriba en el CSV con IF salteo ese registro
            writer.writerow([row["nombre"], row["util"], row["dif"], row["maximo"], row["minimo"], row["fecha"], datetime.now()])

# %%
# importar libreria de panda para trabajar con datos tabulados
import pandas as pd
import codecs # Esta libreria la utilizo para acomodar el decodificado de caracteres.

# Esta linea decodifica el archivo CSV para que quede en UTF-8
with codecs.open(r"C:\Users\Vir\Desktop\SDIA\Practica\TP2\Codigo Vir\Repo-Paralelo-de-PP\bolsa_de_madrid.csv", 'r', encoding='utf-8',
                 errors='ignore') as fdata:
# instancio pandas  (con pd) y llamo a la funcion read_csv el cual lee el archivo CSV y lo convierte en tabla
    df = pd.read_csv(fdata)

df
# Out:
#       Unnamed: 0         0    0.1       0.2       0.3  Unnamed: 5  \
# 0        ACCIONA  148,1000   3,06  149,5000  144,6000  13/09/2021
# 1       ACERINOX   11,3550  -0,26   11,4900   11,2700  13/09/2021
# 2            ACS   23,4000   4,00   23,5300   22,6700  13/09/2021
# 3           AENA  133,5000   1,56  134,1000  132,0000  13/09/2021
# 4       ALMIRALL   13,9400   0,65   14,0600   13,7600  13/09/2021
# 5        AMADEUS   52,0000   0,62   52,5800   51,6400  13/09/2021
# 6    ARCELORMIT.   27,9050  -0,02   28,3750   27,7650  13/09/2021
# 7    B.SANTANDER    3,1140   2,33    3,1140    3,0485  13/09/2021
# 8    BA.SABADELL    0,6008   3,09    0,6016    0,5824  13/09/2021
# 9      BANKINTER    4,9430   1,54    4,9500    4,8570  13/09/2021
# 10          BBVA    5,5970   1,76    5,6020    5,4820  13/09/2021
# 11     CAIXABANK    2,6420   2,44    2,6420    2,5760  13/09/2021
# 12       CELLNEX   56,6600  -1,01   57,5600   56,6600  13/09/2021
# 13  CIE AUTOMOT.   23,7000   0,77   23,8000   23,4400  13/09/2021
# 14        ENAGAS   18,8900   1,42   18,9350   18,6450  13/09/2021
